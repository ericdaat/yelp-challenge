# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.naive_bayes import BernoulliNB
from sklearn.linear_model import SGDClassifier

# %%
dfs = pd.read_json('/Users/eric/Code/yelp-challenge/dataset/yelp_academic_dataset_review.json',
                   lines=True,
                   chunksize=5000)

# %%
v = HashingVectorizer()
# clf = BernoulliNB()
clf = SGDClassifier()

# %%
for i, df_ in enumerate(dfs):
    df_['sentiment'] = df_['stars'].apply(lambda r: 1 if r > 3 else 0)
    
    text_train, text_val, target_train, target_val = \
        train_test_split(df_['text'], df_['sentiment'])
    
    clf.partial_fit(X=v.transform(text_train),
                    y=target_train,
                    classes=[0, 1])
    
    val_score = clf.score(v.transform(text_val), target_val)
    
    print 'Batch {0}, val score {1}'.format(i+1, val_score)
# Out:
# Batch 1, val score 0.8376
# Batch 2, val score 0.7568
# Batch 3, val score 0.8472
# Batch 4, val score 0.8504
# Batch 5, val score 0.8272
# Batch 6, val score 0.7992
# Batch 7, val score 0.8096
# Batch 8, val score 0.812
# Batch 9, val score 0.8496
# Batch 10, val score 0.8072
# Batch 11, val score 0.8944
# Batch 12, val score 0.8304
# Batch 13, val score 0.8096
# Batch 14, val score 0.8648
# Batch 15, val score 0.8288
# Batch 16, val score 0.8272
# Batch 17, val score 0.8312
# Batch 18, val score 0.8272
# Batch 19, val score 0.8672
# Batch 20, val score 0.8328
# Batch 21, val score 0.86
# Batch 22, val score 0.8496
# Batch 23, val score 0.8536
# Batch 24, val score 0.8608
# Batch 25, val score 0.8624
# Batch 26, val score 0.8496
# Batch 27, val score 0.8392
# Batch 28, val score 0.844
# Batch 29, val score 0.82
# Batch 30, val score 0.8016
# Batch 31, val score 0.872
# Batch 32, val score 0.8816
# Batch 33, val score 0.856
# Batch 34, val score 0.8504
# Batch 35, val score 0.8496
# Batch 36, val score 0.812
# Batch 37, val score 0.8624
# Batch 38, val score 0.8352
# Batch 39, val score 0.872
# Batch 40, val score 0.9008
# Batch 41, val score 0.836
# Batch 42, val score 0.8656
# Batch 43, val score 0.8576
# Batch 44, val score 0.8656
# Batch 45, val score 0.8736
# Batch 46, val score 0.836
# Batch 47, val score 0.8528
# Batch 48, val score 0.8728
# Batch 49, val score 0.8592
# Batch 50, val score 0.832
# Batch 51, val score 0.8672
# Batch 52, val score 0.8304
# Batch 53, val score 0.8464
# Batch 54, val score 0.8768
# Batch 55, val score 0.8528
# Batch 56, val score 0.8936
# Batch 57, val score 0.896
# Batch 58, val score 0.8624
# Batch 59, val score 0.8632
# Batch 60, val score 0.8744
# Batch 61, val score 0.8904
# Batch 62, val score 0.888
# Batch 63, val score 0.8624
# Batch 64, val score 0.8856
# Batch 65, val score 0.8696
# Batch 66, val score 0.88
# Batch 67, val score 0.8776
# Batch 68, val score 0.852
# Batch 69, val score 0.8608
# Batch 70, val score 0.8832
# Batch 71, val score 0.8744
# Batch 72, val score 0.8728
# Batch 73, val score 0.8816
# Batch 74, val score 0.8864
# Batch 75, val score 0.8784
# Batch 76, val score 0.896
# Batch 77, val score 0.8832
# Batch 78, val score 0.8776
# Batch 79, val score 0.8536
# Batch 80, val score 0.8352
# Batch 81, val score 0.844
# Batch 82, val score 0.876
# Batch 83, val score 0.8672
# Batch 84, val score 0.8288
# Batch 85, val score 0.8528
# Batch 86, val score 0.8448
# Batch 87, val score 0.8408
# Batch 88, val score 0.8552
# Batch 89, val score 0.852
# Batch 90, val score 0.884
# Batch 91, val score 0.8544
# Batch 92, val score 0.8496
# Batch 93, val score 0.8568
# Batch 94, val score 0.8536
# Batch 95, val score 0.864
# Batch 96, val score 0.8392
# Batch 97, val score 0.8704
# Batch 98, val score 0.8632
# Batch 99, val score 0.8504
# Batch 100, val score 0.8512
# Batch 101, val score 0.8584
# Batch 102, val score 0.8512
# Batch 103, val score 0.8448
# Batch 104, val score 0.8664
# Batch 105, val score 0.8672
# Batch 106, val score 0.8592
# Batch 107, val score 0.8736
# Batch 108, val score 0.8632
# Batch 109, val score 0.8648
# Batch 110, val score 0.8736
# Batch 111, val score 0.8864
# Batch 112, val score 0.8872
# Batch 113, val score 0.8608
# Batch 114, val score 0.8536
# Batch 115, val score 0.8472
# Batch 116, val score 0.8768
# Batch 117, val score 0.8464
# Batch 118, val score 0.808
# Batch 119, val score 0.8344
# Batch 120, val score 0.8464
# Batch 121, val score 0.8216
# Batch 122, val score 0.8112
# Batch 123, val score 0.8232
# Batch 124, val score 0.8232
# Batch 125, val score 0.8328
# Batch 126, val score 0.8608
# Batch 127, val score 0.8464
# Batch 128, val score 0.8832
# Batch 129, val score 0.8688
# Batch 130, val score 0.8704
# Batch 131, val score 0.8816
# Batch 132, val score 0.8736
# Batch 133, val score 0.8864
# Batch 134, val score 0.8712
# Batch 135, val score 0.7912
# Batch 136, val score 0.8192
# Batch 137, val score 0.8192
# Batch 138, val score 0.8104
# Batch 139, val score 0.8896
# Batch 140, val score 0.896
# Batch 141, val score 0.8624
# Batch 142, val score 0.8824
# Batch 143, val score 0.8472
# Batch 144, val score 0.8744
# Batch 145, val score 0.8792
# Batch 146, val score 0.8712
# Batch 147, val score 0.8736
# Batch 148, val score 0.8808
# Batch 149, val score 0.864
# Batch 150, val score 0.8704
# Batch 151, val score 0.8816
# Batch 152, val score 0.884
# Batch 153, val score 0.8792
# Batch 154, val score 0.8448
# Batch 155, val score 0.8488
# Batch 156, val score 0.852
# Batch 157, val score 0.8608
# Batch 158, val score 0.8712
# Batch 159, val score 0.8864
# Batch 160, val score 0.8632
# Batch 161, val score 0.8536
# Batch 162, val score 0.848
# Batch 163, val score 0.8608
# Batch 164, val score 0.8688
# Batch 165, val score 0.8536
# Batch 166, val score 0.8816
# Batch 167, val score 0.8632
# Batch 168, val score 0.8752
# Batch 169, val score 0.848
# Batch 170, val score 0.8664
# Batch 171, val score 0.88
# Batch 172, val score 0.8752
# Batch 173, val score 0.8632
# Batch 174, val score 0.8488
# Batch 175, val score 0.8672
# Batch 176, val score 0.8704
# Batch 177, val score 0.8624
# Batch 178, val score 0.8712
# Batch 179, val score 0.8656
# Batch 180, val score 0.8544
# Batch 181, val score 0.8896
# Batch 182, val score 0.8768
# Batch 183, val score 0.8536
# Batch 184, val score 0.8736
# Batch 185, val score 0.8648
# Batch 186, val score 0.884
# Batch 187, val score 0.8904
# Batch 188, val score 0.892
# Batch 189, val score 0.8888
# Batch 190, val score 0.8832
# Batch 191, val score 0.9064
# Batch 192, val score 0.8872
# Batch 193, val score 0.8952
# Batch 194, val score 0.888
# Batch 195, val score 0.8984
# Batch 196, val score 0.8728
# Batch 197, val score 0.8896
# Batch 198, val score 0.8896
# Batch 199, val score 0.8856
# Batch 200, val score 0.872
# Batch 201, val score 0.8816
# Batch 202, val score 0.868
# Batch 203, val score 0.8488
# Batch 204, val score 0.8672
# Batch 205, val score 0.8504
# Batch 206, val score 0.8344
# Batch 207, val score 0.864
# Batch 208, val score 0.8664
# Batch 209, val score 0.8776
# Batch 210, val score 0.8496
# Batch 211, val score 0.8312
# Batch 212, val score 0.8848
# Batch 213, val score 0.86
# Batch 214, val score 0.8792
# Batch 215, val score 0.8376
# Batch 216, val score 0.824
# Batch 217, val score 0.8288
# Batch 218, val score 0.8824
# Batch 219, val score 0.8584
# Batch 220, val score 0.8704
# Batch 221, val score 0.8824
# Batch 222, val score 0.8744
# Batch 223, val score 0.8656
# Batch 224, val score 0.8608
# Batch 225, val score 0.8776
# Batch 226, val score 0.8968
# Batch 227, val score 0.8688
# Batch 228, val score 0.8712
# Batch 229, val score 0.8816
# Batch 230, val score 0.88
# Batch 231, val score 0.8776
# Batch 232, val score 0.864
# Batch 233, val score 0.8624
# Batch 234, val score 0.844
# Batch 235, val score 0.8504
# Batch 236, val score 0.8576
# Batch 237, val score 0.8728
# Batch 238, val score 0.8832
# Batch 239, val score 0.8928
# Batch 240, val score 0.904
# Batch 241, val score 0.8888
# Batch 242, val score 0.8888
# Batch 243, val score 0.8864
# Batch 244, val score 0.8784
# Batch 245, val score 0.888
# Batch 246, val score 0.8736
# Batch 247, val score 0.9008
# Batch 248, val score 0.9032
# Batch 249, val score 0.8704
# Batch 250, val score 0.9192
# Batch 251, val score 0.8696
# Batch 252, val score 0.8912
# Batch 253, val score 0.876
# Batch 254, val score 0.8912
# Batch 255, val score 0.8936
# Batch 256, val score 0.9064
# Batch 257, val score 0.9056
# Batch 258, val score 0.8928
# Batch 259, val score 0.892
# Batch 260, val score 0.872
# Batch 261, val score 0.8896
# Batch 262, val score 0.9
# Batch 263, val score 0.8968
# Batch 264, val score 0.8736
# Batch 265, val score 0.9088
# Batch 266, val score 0.9072
# Batch 267, val score 0.8824
# Batch 268, val score 0.8912
# Batch 269, val score 0.8928
# Batch 270, val score 0.9
# Batch 271, val score 0.8992
# Batch 272, val score 0.9144
# Batch 273, val score 0.8784
# Batch 274, val score 0.8912
# Batch 275, val score 0.8848
# Batch 276, val score 0.8984
# Batch 277, val score 0.9056
# Batch 278, val score 0.876
# Batch 279, val score 0.876
# Batch 280, val score 0.8744
# Batch 281, val score 0.8752
# Batch 282, val score 0.9016
# Batch 283, val score 0.8816
# Batch 284, val score 0.8872
# Batch 285, val score 0.8912
# Batch 286, val score 0.8848
# Batch 287, val score 0.9048
# Batch 288, val score 0.8896
# Batch 289, val score 0.8952
# Batch 290, val score 0.892
# Batch 291, val score 0.8888
# Batch 292, val score 0.8856
# Batch 293, val score 0.8744
# Batch 294, val score 0.892
# Batch 295, val score 0.88
# Batch 296, val score 0.8832
# Batch 297, val score 0.8944
# Batch 298, val score 0.8736
# Batch 299, val score 0.8752
# Batch 300, val score 0.8976
# Batch 301, val score 0.8728
# Batch 302, val score 0.8936
# Batch 303, val score 0.8952
# Batch 304, val score 0.9064
# Batch 305, val score 0.9008
# Batch 306, val score 0.892
# Batch 307, val score 0.8808
# Batch 308, val score 0.8896
# Batch 309, val score 0.9008
# Batch 310, val score 0.8968
# Batch 311, val score 0.896
# Batch 312, val score 0.8856
# Batch 313, val score 0.904
# Batch 314, val score 0.872
# Batch 315, val score 0.9072
# Batch 316, val score 0.9144
# Batch 317, val score 0.8864
# Batch 318, val score 0.8928
# Batch 319, val score 0.9216
# Batch 320, val score 0.916
# Batch 321, val score 0.8704
# Batch 322, val score 0.8944
# Batch 323, val score 0.8688
# Batch 324, val score 0.8928
# Batch 325, val score 0.9072
# Batch 326, val score 0.8968
# Batch 327, val score 0.8992
# Batch 328, val score 0.9064
# Batch 329, val score 0.9
# Batch 330, val score 0.9136
# Batch 331, val score 0.9088
# Batch 332, val score 0.8856
# Batch 333, val score 0.8944
# Batch 334, val score 0.9096
# Batch 335, val score 0.9048
# Batch 336, val score 0.9032
# Batch 337, val score 0.9168
# Batch 338, val score 0.8888
# Batch 339, val score 0.9064
# Batch 340, val score 0.9104
# Batch 341, val score 0.8896
# Batch 342, val score 0.9048
# Batch 343, val score 0.8896
# Batch 344, val score 0.896
# Batch 345, val score 0.9048
# Batch 346, val score 0.9144
# Batch 347, val score 0.9064
# Batch 348, val score 0.92
# Batch 349, val score 0.9184
# Batch 350, val score 0.8944
# Batch 351, val score 0.8992
# Batch 352, val score 0.8952
# Batch 353, val score 0.9056
# Batch 354, val score 0.9072
# Batch 355, val score 0.8888
# Batch 356, val score 0.9096
# Batch 357, val score 0.884
# Batch 358, val score 0.904
# Batch 359, val score 0.8696
# Batch 360, val score 0.9096
# Batch 361, val score 0.8992
# Batch 362, val score 0.9088
# Batch 363, val score 0.884
# Batch 364, val score 0.9048
# Batch 365, val score 0.8912
# Batch 366, val score 0.8992
# Batch 367, val score 0.916
# Batch 368, val score 0.9032
# Batch 369, val score 0.8936
# Batch 370, val score 0.8848
# Batch 371, val score 0.9128
# Batch 372, val score 0.908
# Batch 373, val score 0.9048
# Batch 374, val score 0.9016
# Batch 375, val score 0.908
# Batch 376, val score 0.9168
# Batch 377, val score 0.9056
# Batch 378, val score 0.8968
# Batch 379, val score 0.9
# Batch 380, val score 0.8992
# Batch 381, val score 0.9248
# Batch 382, val score 0.9232
# Batch 383, val score 0.912
# Batch 384, val score 0.896
# Batch 385, val score 0.9016
# Batch 386, val score 0.9
# Batch 387, val score 0.888
# Batch 388, val score 0.9232
# Batch 389, val score 0.92
# Batch 390, val score 0.8936
# Batch 391, val score 0.9104
# Batch 392, val score 0.8968
# Batch 393, val score 0.9128
# Batch 394, val score 0.9032
# Batch 395, val score 0.9152
# Batch 396, val score 0.8728
# Batch 397, val score 0.9008
# Batch 398, val score 0.9088
# Batch 399, val score 0.8808
# Batch 400, val score 0.9024
# Batch 401, val score 0.9016
# Batch 402, val score 0.908
# Batch 403, val score 0.9304
# Batch 404, val score 0.9136
# Batch 405, val score 0.9224
# Batch 406, val score 0.9248
# Batch 407, val score 0.92
# Batch 408, val score 0.9176
# Batch 409, val score 0.9128
# Batch 410, val score 0.9112
# Batch 411, val score 0.8992
# Batch 412, val score 0.9256
# Batch 413, val score 0.9264
# Batch 414, val score 0.9208
# Batch 415, val score 0.9216
# Batch 416, val score 0.9176
# Batch 417, val score 0.9256
# Batch 418, val score 0.9248
# Batch 419, val score 0.92
# Batch 420, val score 0.9136
# Batch 421, val score 0.9216
# Batch 422, val score 0.9088
# Batch 423, val score 0.9136
# Batch 424, val score 0.916
# Batch 425, val score 0.9096
# Batch 426, val score 0.9248
# Batch 427, val score 0.9184
# Batch 428, val score 0.916
# Batch 429, val score 0.9072
# Batch 430, val score 0.764705882353
